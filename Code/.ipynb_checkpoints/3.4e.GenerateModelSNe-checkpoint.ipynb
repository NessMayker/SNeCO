# %% [markdown]
# Generate random (area) placement files

# %%
#import packages and initialize settings
import time
import os
import numpy as np
from astropy.io import fits, ascii
import astropy.io.fits as pyfits
from astropy.wcs import WCS
from matplotlib import pyplot as plt
from astropy.coordinates import SkyCoord
import astropy.units as u
from astropy.table import Table


plt.rc('text',usetex=True)
fontsize=20
plt.rc('xtick',labelsize=fontsize)
plt.rc('ytick',labelsize=fontsize)

import sys
# Work Laptop:     
#sys.path.append('/Users/mayker.1/Desktop/NessPythonFunctions')
# Work Desktop:    
sys.path.append('/home/mayker.1/Desktop/NessPythonFunctions')
# Personal Laptop: sys.path.append('/Users/nessmayker/Desktop/NessPythonFunctions')
from deprojectGalaxy import deproject
from FindNearestMC import int2mass, mass2int, arraySort, findNearest, printNearest
from distanceCalc import distance
from normalize import norm

# %%
#Get Galaxy names, distances, and fits file locations

# Unpack master table to get SNe information
database = Table.read('../Data/3.SNe+GalData.csv', format = "csv")

database[0:1]
# Out:
# <Table length=1>
#  galaxy  ...
#   str8   ...
# -------- ...
# circinus ...

# %%
galaxy = database["galaxy"]
galDist = database["dist"]

#Make lists unique for galaxies (no repeating galaxies or distances)    
def unique(origGalsList, origDistList): 
    uniqueGalsList, uniqueDistList = [],[] 
    for i in range(len(origGalsList)): 
        if origGalsList[i] not in uniqueGalsList: 
            uniqueGalsList.append(origGalsList[i]) 
            uniqueDistList.append(origDistList[i])
    return(uniqueGalsList, uniqueDistList)

gals, dists = unique(galaxy, galDist)

# %%
def runModels(gals, dists,modelType = 2):

    MassArray = [10**(5.5), 10**6, 10**(6.5)]
    MassDescriptor = ["10E55", "10E6", "10E65"]

    for m in range(len(MassArray)):
        val, dist, galaxyUsed, run, randX, randY = [],[],[],[],[],[]
        for i in range(len(gals)):
            filestr = gals[i] + '_'
            fileName = "/home/mayker.1/Desktop/SNeCO_Data_Products/FlatGalaxyMaps/{}FlatData.txt".format(filestr)
            if os.path.isfile(fileName):
                table = Table.read(fileName, format = "ascii")
                dx = table["dx"]
                dy = table["dy"]
                inten = table["Intensity"]

                for j in range(100):

                    #if model is random
                    if modelType == 1:
                        numrowsX = len(dx)    
                        numrowsY = len(dy)  

                        randIntX = np.random.randint(low=0, high=numrowsX)
                        randIntY = np.random.randint(low=0, high=numrowsY)
                    
                    #if model is gas density weighted
                    else:
                        intArr = np.clip(inten, a_min=0.0, a_max=None)
                        total = sum(intArr)
                        prob  = intArr/total 
                        prob  = norm(prob)
                        nX = len(dx)
                        nY = len(dy)
                        indiciesX = np.arange(nX, dtype=int)
                        randIntX = np.random.choice(indiciesX, p=prob)
                        indiciesY = np.arange(nY, dtype=int)
                        randIntY = np.random.choice(indiciesY, p=prob)
                    
                    
                    rX   = dx[randIntX]
                    rY   = dy[randIntY]

                    distRand = []
                    distRand = distance(dx, rX, dy, rY, dists[i])

                    distance2, value = printNearest(filestr, "Mass", MassArray[m], SNRcutoff = 3.0, test="Model", distList=distRand)
                    val.append(value)
                    dist.append(distance2)
                    randX.append(rX)
                    randY.append(rY)
                    galaxyUsed.append(gals[i])
                    run.append(j)       

                print(MassDescriptor[m],":",gals[i]," ", i, ": Ran 100 experiments.")


                descriptor = "_Mass_{}".format(MassDescriptor[m])
            else:
                print("Error with", gals[i])
            with open ("../Data/RandomMaps/Results{}.txt".format(descriptor), "w") as text_file:
                print('#Galaxy,    Value,    Distance,    Run,     randX,     randY', file = text_file)
                for k in range(len(run)):
                    print(galaxyUsed[k], val[k], dist[k], run[k], randX[k], randY[k], file = text_file)

#runModels(gals, dists, modelType = 1)
runModels(gals, dists, modelType = 2)
# Out:
# 10E55 : circinus   0 : Ran 100 random placement (area) experiments.
# 10E55 : ngc0253   1 : Ran 100 random placement (area) experiments.
# 10E55 : ngc0300   2 : Ran 100 random placement (area) experiments.
# 10E55 : ngc0628   3 : Ran 100 random placement (area) experiments.
# Error with ngc1068
# 10E55 : ngc1087   5 : Ran 100 random placement (area) experiments.
# 10E55 : ngc1097   6 : Ran 100 random placement (area) experiments.
# 10E55 : ngc1365   7 : Ran 100 random placement (area) experiments.
# 10E55 : ngc1433   8 : Ran 100 random placement (area) experiments.
# 10E55 : ngc1511   9 : Ran 100 random placement (area) experiments.
# 10E55 : ngc1559   10 : Ran 100 random placement (area) experiments.
# 10E55 : ngc1566   11 : Ran 100 random placement (area) experiments.
# 10E55 : ngc1637   12 : Ran 100 random placement (area) experiments.
# Error with ngc1672
# 10E55 : ngc2775   14 : Ran 100 random placement (area) experiments.
# 10E55 : ngc2997   15 : Ran 100 random placement (area) experiments.
# 10E55 : ngc3239   16 : Ran 100 random placement (area) experiments.
# 10E55 : ngc3627   17 : Ran 100 random placement (area) experiments.
# 10E55 : ngc4254   18 : Ran 100 random placement (area) experiments.
# 10E55 : ngc4303   19 : Ran 100 random placement (area) experiments.
# 10E55 : ngc4321   20 : Ran 100 random placement (area) experiments.
# 10E55 : ngc4424   21 : Ran 100 random placement (area) experiments.
# 10E55 : ngc4457   22 : Ran 100 random placement (area) experiments.
# 10E55 : ngc4496a   23 : Ran 100 random placement (area) experiments.
# 10E55 : ngc4536   24 : Ran 100 random placement (area) experiments.
# Error with ngc4579
# 10E55 : ngc4945   26 : Ran 100 random placement (area) experiments.
# 10E55 : ngc5128   27 : Ran 100 random placement (area) experiments.
# 10E55 : ngc5236   28 : Ran 100 random placement (area) experiments.
# 10E55 : ngc5530   29 : Ran 100 random placement (area) experiments.
# 10E55 : ngc6744   30 : Ran 100 random placement (area) experiments.
# 10E55 : ngc7793   31 : Ran 100 random placement (area) experiments.
# 10E6 : circinus   0 : Ran 100 random placement (area) experiments.
# 10E6 : ngc0253   1 : Ran 100 random placement (area) experiments.
# 10E6 : ngc0300   2 : Ran 100 random placement (area) experiments.
# 10E6 : ngc0628   3 : Ran 100 random placement (area) experiments.
# Error with ngc1068
# 10E6 : ngc1087   5 : Ran 100 random placement (area) experiments.
# 10E6 : ngc1097   6 : Ran 100 random placement (area) experiments.
# 10E6 : ngc1365   7 : Ran 100 random placement (area) experiments.
# 10E6 : ngc1433   8 : Ran 100 random placement (area) experiments.
# 10E6 : ngc1511   9 : Ran 100 random placement (area) experiments.
# 10E6 : ngc1559   10 : Ran 100 random placement (area) experiments.
# 10E6 : ngc1566   11 : Ran 100 random placement (area) experiments.
# 10E6 : ngc1637   12 : Ran 100 random placement (area) experiments.
# Error with ngc1672
# 10E6 : ngc2775   14 : Ran 100 random placement (area) experiments.
# 10E6 : ngc2997   15 : Ran 100 random placement (area) experiments.
# 10E6 : ngc3239   16 : Ran 100 random placement (area) experiments.
# 10E6 : ngc3627   17 : Ran 100 random placement (area) experiments.
# 10E6 : ngc4254   18 : Ran 100 random placement (area) experiments.
# 10E6 : ngc4303   19 : Ran 100 random placement (area) experiments.
# 10E6 : ngc4321   20 : Ran 100 random placement (area) experiments.
# 10E6 : ngc4424   21 : Ran 100 random placement (area) experiments.
# 10E6 : ngc4457   22 : Ran 100 random placement (area) experiments.
# 10E6 : ngc4496a   23 : Ran 100 random placement (area) experiments.
# 10E6 : ngc4536   24 : Ran 100 random placement (area) experiments.
# Error with ngc4579
# 10E6 : ngc4945   26 : Ran 100 random placement (area) experiments.
# 10E6 : ngc5128   27 : Ran 100 random placement (area) experiments.
# 10E6 : ngc5236   28 : Ran 100 random placement (area) experiments.
# 10E6 : ngc5530   29 : Ran 100 random placement (area) experiments.
# 10E6 : ngc6744   30 : Ran 100 random placement (area) experiments.
# 10E6 : ngc7793   31 : Ran 100 random placement (area) experiments.
# 10E65 : circinus   0 : Ran 100 random placement (area) experiments.
# 10E65 : ngc0253   1 : Ran 100 random placement (area) experiments.
# 10E65 : ngc0300   2 : Ran 100 random placement (area) experiments.
# 10E65 : ngc0628   3 : Ran 100 random placement (area) experiments.
# Error with ngc1068
# 10E65 : ngc1087   5 : Ran 100 random placement (area) experiments.
# 10E65 : ngc1097   6 : Ran 100 random placement (area) experiments.
# 10E65 : ngc1365   7 : Ran 100 random placement (area) experiments.
# 10E65 : ngc1433   8 : Ran 100 random placement (area) experiments.
# 10E65 : ngc1511   9 : Ran 100 random placement (area) experiments.
# 10E65 : ngc1559   10 : Ran 100 random placement (area) experiments.
# 10E65 : ngc1566   11 : Ran 100 random placement (area) experiments.
# 10E65 : ngc1637   12 : Ran 100 random placement (area) experiments.
# Error with ngc1672
# 10E65 : ngc2775   14 : Ran 100 random placement (area) experiments.
# 10E65 : ngc2997   15 : Ran 100 random placement (area) experiments.
# 10E65 : ngc3239   16 : Ran 100 random placement (area) experiments.
# 10E65 : ngc3627   17 : Ran 100 random placement (area) experiments.
# 10E65 : ngc4254   18 : Ran 100 random placement (area) experiments.
# 10E65 : ngc4303   19 : Ran 100 random placement (area) experiments.
# 10E65 : ngc4321   20 : Ran 100 random placement (area) experiments.
# 10E65 : ngc4424   21 : Ran 100 random placement (area) experiments.
# 10E65 : ngc4457   22 : Ran 100 random placement (area) experiments.
# 10E65 : ngc4496a   23 : Ran 100 random placement (area) experiments.
# 10E65 : ngc4536   24 : Ran 100 random placement (area) experiments.
# Error with ngc4579
# 10E65 : ngc4945   26 : Ran 100 random placement (area) experiments.
# 10E65 : ngc5128   27 : Ran 100 random placement (area) experiments.
# 10E65 : ngc5236   28 : Ran 100 random placement (area) experiments.
# 10E65 : ngc5530   29 : Ran 100 random placement (area) experiments.
# 10E65 : ngc6744   30 : Ran 100 random placement (area) experiments.
# 10E65 : ngc7793   31 : Ran 100 random placement (area) experiments.
